# %% [markdown]
# ### Задание 4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.pi

# %%
x = np.linspace(-np.pi, np.pi, 200)
plt.plot(x, np.cos(x*1))
plt.plot(x, np.cos(x*4))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()

# %% [markdown]
# ### Задания к уроку 2

# %% [markdown]
# 1. Задание

# %%
X = [20, 20, 20] 
Y= [0, 0, 20]
Z = np.sqrt(X[0]**2+X[1]**2+X[2]**2) + np.sqrt(Y[0]**2+Y[1]**2+Y[2]**2)
Z
# Out:
# 54.64101615137755

# %% [markdown]
# 2. Задание (на листочке)
# Почему прямые не кажутся перпендикулярными? (см.ролик)
#
# ### по мне так из за разности в масштабе по осям Х и Y

# %%
x = np.linspace(-5, 5, 21)
y = 3*x+1
y2= (-1/3)*x+1
plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-15, 15)
# Out:
# (-15, 15)

# %% [markdown]
# 3. Задание (в программе)
# Напишите код на Python, реализующий построение графиков:
# окружности,
# эллипса,
# гиперболы.
# ### ТУт у меня пока проблемы

# %%
import math
x = []
y1 = []
y2= []
R = 20
for i in range(-10, 100):
    x_ = i/10
    x.append(x_)
    y1.append(math.sqrt(R**2-x_**2))

plt.plot(x, y1)

plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x = []
y1 = []
y2= []
p = 4
for i in range(1000):
    x_ = i/1000
    x.append(x_)
    y1.append(np.pi(2*p*x_))
    y2.append(-math.sqrt(2*p*x_))
plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
